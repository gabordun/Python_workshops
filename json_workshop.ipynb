# %% [markdown]
# <a href="https://colab.research.google.com/github/gabordun/Python_workshops/blob/master/json_workshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = {key}

# %%
import json
import numpy as np
import pandas as pd

# %%
with open('/content/example_1.json') as json_file:
  data = json.load(json_file)
  print(data)
# Out:
# {'fruit': 'Apple', 'size': 'Large', 'color': 'Red'}

# %%
with open('/content/example_2.json') as json_file:
  data2 = json.load(json_file)
  print(data2)
# Out:
# {'quiz': {'sport': {'q1': {'question': 'Which one is correct team name in NBA?', 'options': ['New York Bulls', 'Los Angeles Kings', 'Golden State Warriros', 'Huston Rocket'], 'answer': 'Huston Rocket'}}, 'maths': {'q1': {'question': '5 + 7 = ?', 'options': ['10', '11', '12', '13'], 'answer': '12'}, 'q2': {'question': '12 - 8 = ?', 'options': ['1', '2', '3', '4'], 'answer': '4'}}}}

# %%
data2['quiz']['sport']['q1']['options'][0]
# Out:
# 'New York Bulls'

# %%
with open('/content/sample.json') as json_file:
  data3 = json.load(json_file)

# %%
for i in range(0,len(data3)):
 print({data3[i]['position']['lat'],data3[i]['position']['lng']})
# Out:
# {50.882189999999994, 6.8791899999999995}
# {50.8785847, 6.869691899999999}
# {50.86875, 6.878909999999999}
# {50.8816932, 6.8924376999999994}
# {50.8804712, 6.8828784}
# {50.8798283, 6.8895865}
# {50.8811325, 6.891100799999999}
# {50.8753567, 6.8401776}
# {50.8828884, 6.8616021}
# {50.8713951, 6.8914693}
# {50.880741799999996, 6.8916501}
# {50.882079999999995, 6.880039999999999}
# {50.87003, 6.8685599999999996}
# {50.8813545, 6.8842175}
# {50.8808954, 6.8933728}
# {50.879497799999996, 6.889079499999999}
# {50.878849599999995, 6.875437499999999}
# {50.872758, 6.887906}
# {50.869316999999995, 6.8951034}
# {50.8816306, 6.8747646}
# {50.8800793, 6.8831916}
# {50.8802148, 6.867292}
# {50.86993, 6.868259999999999}
# {50.881049399999995, 6.8916618}
# {50.878701899999996, 6.8743789}
# {50.87946, 6.87651}
# {50.8727958, 6.871843999999999}
# {50.8787695, 6.8676812}
# {50.8796826, 6.8787696}
# {50.8731836, 6.8889884}
# {50.8752638, 6.8899566}
# {50.8668476, 6.8754194}
# ...

# %%
latitude = []
longitude = []
wheelchair = []
for i in range(0,len(data3)):
  latitude.append(data3[i]['position']['lat'])
  longitude.append(data3[i]['position']['lng'])
  try:
    if(data3[i]['architecture']):
      if(data3[i]['architecture']['wheelchair']):
        wheelchair.append(data3[i]['architecture']['wheelchair'])
      else:
        wheelchair.append('NA')
  except:
    wheelchair.append('NA')
    continue
  
df = pd.DataFrame(data = {'Latitude':latitude,'Longitude':longitude,'Wheelchair':wheelchair})
df
# Out:
#        Latitude  Longitude Wheelchair
# 0     50.882190   6.879190         NA
# 1     50.878585   6.869692         NA
# 2     50.868750   6.878910         NA
# 3     50.881693   6.892438         no
# 4     50.880471   6.882878         NA
# 5     50.879828   6.889587         NA
# 6     50.881132   6.891101         NA
# 7     50.875357   6.840178         NA
# 8     50.882888   6.861602         NA
# 9     50.871395   6.891469         NA
# 10    50.880742   6.891650    limited
# 11    50.882080   6.880040         NA
# 12    50.870030   6.868560         NA
# 13    50.881355   6.884218         NA
# 14    50.880895   6.893373         NA
# 15    50.879498   6.889079         NA
# 16    50.878850   6.875437        yes
# 17    50.872758   6.887906         NA
# 18    50.869317   6.895103         NA
# 19    50.881631   6.874765         NA
# 20    50.880079   6.883192         NA
# 21    50.880215   6.867292         NA
# 22    50.869930   6.868260         NA
# 23    50.881049   6.891662         no
# ...

# %%
df.head()
# Out:
#     Latitude  Longitude Wheelchair
# 0  50.882190   6.879190         NA
# 1  50.878585   6.869692         NA
# 2  50.868750   6.878910         NA
# 3  50.881693   6.892438         no
# 4  50.880471   6.882878         NA
